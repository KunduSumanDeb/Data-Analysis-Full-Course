# %%
# creating a tuple

empty_tuple = ()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst = list()
print(type(lst))
tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers = tuple([1,2,3,4,5,6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
numbers = list((1,2,3,4,5,6))
numbers
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuple = (1, "Suman", 23.4, True)
print(mixed_tuple)
# Out:
# (1, 'Suman', 23.4, True)

# %%
# Accessing Tuple Elements

numbers
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(numbers[2])
print(numbers[-1])
# Out:
# 3
# 6

# %%
numbers[0:4]
# Out:
# [1, 2, 3, 4]

# %%
numbers[::-1]
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
# Tuple Operations

concatination_tuple = numbers + mixed_tuple
print(concatination_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Tuple Operations
# ----> 3 concatination_tuple = numbers + mixed_tuple
#       4 print(concatination_tuple)
#
# TypeError: can only concatenate list (not "tuple") to list

# %%
print(mixed_tuple * 3)
print(numbers * 3)
# Out:
# (1, 'Suman', 23.4, True, 1, 'Suman', 23.4, True, 1, 'Suman', 23.4, True)
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
# Immutable Nature of tuples.
# Elements cannot be changed once assigned.

lst = [1,2,3,4,5] # this is possible in list.
print(lst)
lst[1] = "Suman"
print()

numbers[1] = "Suman"
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuples Method
print(numbers)
print(numbers.count(1))
print(numbers.index(3))
# Out:
# [1, 'Suman', 3, 4, 5, 6]
# 1
# 2

# %%
# Packing and Unpacking 

# Packing
packed_tuple = 1, "Suman", 3.21, True
print(packed_tuple)

#Unpacking
a,b,c,d = packed_tuple
print(a)
print(b)
print(c)
print(d)

#unpacking with *
numbers = (1,2,3,4,5,6)
first,*middle,last = numbers
print(first)
print(middle)
print(last)
# Out:
# (1, 'Suman', 3.21, True)
# 1
# Suman
# 3.21
# True
# 1
# [2, 3, 4, 5]
# 6

# %%
# Nested Tuples
# Nsted List

lst = [[1,2,3,4],[5,6,7,8],[9,"Suman",3.14,"Payel"]]
print(lst[0])
print(lst[0][0:3])
print(lst[0:3])
print(lst[2][0:4])
# Out:
# [1, 2, 3, 4]
# [1, 2, 3]
# [[1, 2, 3, 4], [5, 6, 7, 8], [9, 'Suman', 3.14, 'Payel']]
# [9, 'Suman', 3.14, 'Payel']

# %%
# Access the elements inside the tuple

nested_tuple = ((1,2,3),("a","b","c"),(True,False))
print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
# Iterating over nested tuples

for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item,end = " ")
    print()
# Out:
# 1 2 3
# a b c
# True False
