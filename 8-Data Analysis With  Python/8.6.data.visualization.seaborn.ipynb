# %% [markdown]
# #### Seaborn

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\programming\data_analysis\venv\lib\site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in d:\programming\data_analysis\venv\lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\programming\data_analysis\venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in d:\programming\data_analysis\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\programming\data_analysis\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programming\data_analysis\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\programming\data_analysis\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\programming\data_analysis\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in d:\programming\data_analysis\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in d:\programming\data_analysis\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\programming\data_analysis\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\programming\data_analysis\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\programming\data_analysis\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Basic plotting with Seaborn

tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Create a scatter plot

import matplotlib.pyplot as plt

sns.scatterplot(x = "total_bill", y = "tip", data = tips)
plt.title("Scatter Plot of Total Bill vs Tips")
plt.show()

# %%
# line Plot

sns.lineplot(x='size', y = 'total_bill', data = tips)
plt.title("Line Plot of Toatl bill by size")
plt.show()

# %%
# CATEGORICAL PLOTS

sns.barplot(x = "day", y = "total_bill", data = tips)
plt.title("Bar Plot of Total Bill by Day")
plt.show()

# %%
# BOX PLOT

sns.boxplot(x = "day", y = "total_bill", data = tips)
plt.title("Box Plot of Total Bill by Day")
plt.show()

# %%
# VIOLIN PLOT

sns.violinplot(x = "day", y = "total_bill", data = tips)
plt.title("Violoin Plot of Total Bill by Day")
plt.show()

# %%
# HISTOGRAMS

sns.histplot(x = "day", y = "total_bill", data = tips)
plt.title("Histogram Plot of Total Bill by Day")
plt.show()

# %%
sns.histplot(tips["total_bill"], bins = 10, kde = True) # kde = kernal density
plt.title("Histogram Plot of Total Bill by Day")
plt.show()

# %%
# KDE PLOT

sns.kdeplot(tips["total_bill"], shade = True)
# Out:
# C:\Users\kundu\AppData\Local\Temp\ipykernel_3932\2161368681.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips["total_bill"], shade = True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# PAIR PLOT

sns.pairplot(tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# HEATMAP

corr = tips[["total_bill","tip","size"]].corr()
print(corr)

sns.heatmap(corr,annot = True, cmap = "coolwarm")
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
# <Axes: >

# %%
sales_df = pd.read_csv("data.csv")
sales_df.head()
# Out:
#   Transaction ID        Date Product Category       Product Name  Units Sold  \
# 0         TXN001  2025-01-01      Electronics     Wireless Mouse          15
# 1         TXN002  2025-01-02         Clothing            T-Shirt          22
# 2         TXN003  2025-01-03            Books       Python Guide          10
# 3         TXN004  2025-01-04      Electronics  Bluetooth Speaker           8
# 4         TXN005  2025-01-05          Grocery   Organic Rice 5kg          20
#
#    Unit Price  Total Revenue Region Payment Method
# 0         799          11985   East            UPI
# 1         499          10978  North    Credit Card
# 2         899           8990  South           Cash
# 3        2499          19992   West     Debit Card
# 4         650          13000   East            UPI

# %%
# PLOT TOTAL SALES BY PRODUCT

plt.figure(figsize = (10,6))
sns.barplot(x = "Product Category", y = "Total Revenue", data = sales_df, estimator = sum)
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()

# %%
# PLOT TOTAL SALES BY Region

plt.figure(figsize = (10,6))
sns.barplot(x = "Region", y = "Total Revenue", data = sales_df, estimator = sum)
plt.title("Total Sales by Region")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()
