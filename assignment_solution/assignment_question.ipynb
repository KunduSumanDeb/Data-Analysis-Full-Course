# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
a = int(input("Enter a number: "))
print(f"The number that I entered is : {a}")
# Out:
# The number that I entered is : 12

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
a =  int(input("Enter a number: "))
if a < 0:
    print("The number is negative")
elif a > 0:
    print("The number is positive")
else:
    print("The number is zero")
# Out:
# The number is zero

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
c = int(input("Enter the third number: "))

if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c
print(f"The largest number among {a},{b},{c} is {largest}.")
# Out:
# The largest number among 12,23,1 is 23.

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
def factorial(n):
    if n ==0 or n==1:
        return 1
    else:
        return factorial(n-1) * n
num = int(input("Enter the number: "))
print(f"The factoraila of {num} is {factorial(num)}")
# Out:
# The factoraila of 23 is 25852016738884976640000

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
age = 23
height = 5.3
name = "Suman Deb Kundu"
is_student = True
print(f"Age ({age}) is type: ",type(age))
print(f"Height ({height}) is a type: ",type(height))
print(f"Name ({name}) is a type: ",type(name))
print(f"IS Student ({is_student})is a type: ", type(is_student))
# Out:
# Age (23) is type:  <class 'int'>
# Height (5.3) is a type:  <class 'float'>
# Name (Suman Deb Kundu) is a type:  <class 'str'>
# IS Student (True)is a type:  <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
print(f"Before swapping: a = {a}, b = {b}")
temp = a
a = b
b = temp
print(f"After swapping: a = {a}, b = {b}")
# Out:
# Before swapping: a = 12, b = 23
# After swapping: a = 23, b = 12

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
celsius = float(input("Enter temperature in Celsios: "))
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius} degree Celsius is equal to {fahrenheit} degree Fahrenheit.")
# Out:
# 56.7 degree Celsius is equal to 134.06 degree Fahrenheit.

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
str1 = input ("Enter the first string: ")
str2 = input("Enter the second string: ")
print("Concateniated string: ", str1 +" " + str2)
# Out:
# Concateniated string:  suman payel

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
var = 10.5
if isinstance(var, float):
    print(f"{var} is a float")
else:
    print(f"{var} is not a float")
# Out:
# 10.5 is a float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
a = 10
b = 5
add = a + b
sub = a - b
mul = a * b
div = b / a
print(f"Additon of {a},{b} is result: ",add)
print(f"Subtraction of {a},{b} is result: ",sub)
print(f"Multiplication of {a},{b} is result: ",mul)
print(f"Division of {a},{b} isresult: ",div)
# Out:
# Additon of 10,5 is result:  15
# Subtraction of 10,5 is result:  5
# Multiplication of 10,5 is result:  50
# Division of 10,5 isresult:  0.5

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = 10 
b = 20
print("a > b: ", a > b)
print("a < b: ", a < b)
print("a == b: ", a == b)
print("a != b: ", a != b)
# Out:
# a > b:  False
# a < b:  True
# a == b:  False
# a != b:  True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
x = True
y = False
print(f"x and y: ", x and y)
print(f"x or y: ", x or y)
print(f"not x: ", not x)
# Out:
# x and y:  False
# x or y:  True
# not x:  False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
num = int(input("Enter a number: "))
a = num ** 2
print(f"The square of {num} is {a}.")
# Out:
# The square of 8 is 64.

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
num = int(input("Enter a nnumber: "))
if num % 2 == 0:
    print(f"The number {num} is even.")
else:
    print(f"The number {num} is odd.")
# Out:
# The number 7 is odd.

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
def sum_n(n):
    if n <= 0:
        return 0
    else:
        return sum_n(n-1) + n
n = int(input("Enter a number: "))
print(f"The sum of first {n} natural numbers is {sum_n(n)}")
# Out:
# The sum of first 5 natural numbers is 15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = int(input("Enter the year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"The year {year} is a leap year.")
else:
    print(f"The year {year} is not a leap year.")
# Out:
# The year 2024 is a leap year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
str = input("Enter a string: ")
reversed_string = str[::-1]
print(f"The reversed string is: {reversed_string}")
# Out:
# The reversed string is: leyapnamus

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
str = input("Enter a string: ")
reversed_string = str[::-1]
if str == reversed_string:
    print(f"The string '{str}' is a palindrome.")
# Out:
# The string 'mum' is a palindrome.

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
def sort_ascending(arr):
    n = len(arr)
    for i in range(n):
        for j in range(i + 1, n):
            if arr[i] > arr[j]:
                arr[i], arr[j] = arr[j], arr[i]
    return arr

# Take number of elements
n = int(input("Enter number of elements: "))

# Take list inputs using for loop
numbers = []
for i in range(n):
    num = int(input(f"Enter element {i+1}: "))
    numbers.append(num)

# Display input list
print("Input list:", numbers)

# Sort the list
sorted_list = sort_ascending(numbers)

# Display sorted list
print("Sorted list in ascending order:", sorted_list)
# Out:
# Input list: [3, 2, 0, 8, 4]
# Sorted list in ascending order: [0, 2, 3, 4, 8]
