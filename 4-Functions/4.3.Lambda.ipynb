# %%
# Syntax 

lambda arguments: expression

# %%
def addition(a,b):
    return a+b

# %%
addition(3,4)
# Out:
# 7

# %%
addition = lambda a,b: a+b
print(type(addition))
print(addition(5,6))
# Out:
# <class 'function'>
# 11

# %%
def even(num):
    if num%2 == 0:
        return True
even(24)
# Out:
# True

# %%
even_no = lambda num: num%2 == 0
print(even(12))
# Out:
# True

# %%
def addition(x,y,z):
    return x+y+z
print(addition(23,45,34))
# Out:
# 102

# %%
addition1 = lambda a,b,c:a+b+c 
print(addition(12,23,34))
# Out:
# 69

# %%
# Map Functiojn applies the function to all items of the list.

number = [1,2,3,4,5]

# def squares(number):
#     return number ** 2
# print(squares(2))

square_numbers =

# %%
number = [1,2,3,4,5]
square_numbers = map(lambda x: x**2, number)
print(f"The numbers that are present in the list are : {number}")
print(f"The squares of the numbers taht are present in the list are {square_numbers}")
number = [1,2,3,4,5]
print()
square_numbers = list(map(lambda x: x**2, number))
print(f"The numbers that are present in the list are : {number}")
print(f"The squares of the numbers taht are present in the list are {square_numbers}")
# Out:
# The numbers that are present in the list are : [1, 2, 3, 4, 5]
# The squares of the numbers taht are present in the list are <map object at 0x00000291DB6E6C20>
#
# The numbers that are present in the list are : [1, 2, 3, 4, 5]
# The squares of the numbers taht are present in the list are [1, 4, 9, 16, 25]
