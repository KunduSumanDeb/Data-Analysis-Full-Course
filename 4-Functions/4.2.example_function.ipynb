# %% [markdown]
# ##### Temperature Function

# %%
def Temp_convert(temp,unit):
    """This Function converts temperature between Celcious and Fehrenheit"""
    if unit.lower() == 'c':
        t = temp * 9/5 + 32
        degree = "F"
        return t,degree
    elif unit.lower() == "f":
        t = (temp - 32) * 5/9
        degree = "C"
        return t,degree
    else:
        return None

result = Temp_convert(40, 'F')

if result:
    t, degree = result
    print(f"Temperature: {t} {degree}")
else:
    print("Invalid unit")
# Out:
# Temperature: 4.444444444444445 C

# %% [markdown]
# ##### Password Strength Checker

# %%
def is_strong_pass(password):
    """This Function checks if password is strong or not"""
    if len(password) < 8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char in '!@#$%^&*_+.' for char in password):
        return False
    return True

print(is_strong_pass("Sdkak@10122002"))
# Out:
# True

# %% [markdown]
# ##### Calculate the total Cost Of Items in a shopping Cart.

# %%
def cost_calcuate():

# %% [markdown]
# ##### Check if a string is palindrome.

# %% [markdown]
# ##### Calculate the factorials of a number using recursion.

# %% [markdown]
# ##### A function to read a file and count the frequency of each word.

# %%
def count_freq(file_path):
    word_count = {}
    with open(file_path,'r') as file:
        for line in file:
            words = line.split()
            for word in words:
                word = word.lower().strip('!@#$%^&*_+.\'"')
                word_count[word] = word_count.get(word,0) +1
    return word_count
file_path = 'sample.txt'
word_frequency = count_freq(file_path)
print(word_frequency)
# Out:
# {'hi': 1, 'my': 1, 'name': 1, 'is': 1, 'suman': 1, 'deb': 1, 'kundu': 1, 'i': 1, 'am': 1, 'presently': 1, 'learning': 1, 'data': 1, 'analysis': 1}

# %% [markdown]
# ##### Validate Email Address
