# %%
# Integer Examples

age = 34
type(age)
# Out:
# int

# %%
# Floating Point Example

height = 5.9
print(height)
type(height)
# Out:
# 5.9
# float

# %%
# string Example

name = "Suma Deb Kundu"
print(name)
type(name)
# Out:
# Suma Deb Kundu
# str

# %%
# Boolean Example
True
type(True)
# Out:
# bool

# %%
a = 10
b = 10
a == b
type(a == b)
# Out:
# bool

# %%
result = "Hello" + str(5)
print(result)
# Out:
# Hello5
