# %%
# Basic Syntax rules in python
# Python is case sensitive

name = "Suman"
Name = "Payel"
print(name)
print(Name)
# Out:
# Suman
# Payel

# %%
# Indentation
# Python uses indentation to define blocks of code. Consistent use of spaces (Comonly 4) or a tab is required.

age = 24
if age >= 18:
    print("Your age is", age, ". You are an adult.")
# Out:
# Your age is 24 . You are an adult.

# %%
# Single line comment

print("Hell world")
# Out:
# Hell world

# %%
# Line continuation

total = 1 + 2 + 3 + 4 + \
5 + 6 + 7 + 8 + 9
print("total = ", total)
# Out:
# total =  45

# %%
# multiple statements in a single line

x = 1; y = 2; z = 3; a = x + y + z
print(a)
# Out:
# 6

# %%
# Understand Samnatics in Python
# variable assignment

age = 24
name = "Suman"

# %%
# Type inference

type(age)
# Out:
# int

# %%
# Check the type of the variable 'name'

type(name)
# Out:
# str

# %%
# Type inference

variable = 10
print(type(variable))
variable = "Suman"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 32
if age > 30:
    print(age)
# Out:
# 32

# %%
# Code example of indentation

if True:
    print("Correct Indentation.")
    if False:
        print("This won't be printed.")
    print("This will be printed.")
print("Outside of the block.")
# Out:
# Correct Indentation.
# This will be printed.
# Outside of the block.
