# %% [markdown]
# #### Standard Library Overview

# %%
import array 
arr = array.array('i',[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
# import random

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','strawberry','guava','mango','lichi']))
# Out:
# 10
# guava

# %%
import os
print(os.getcwd())
# Out:
# d:\Programming\Data_Analysis\5-Modules

# %%
# High level operations on files and collections of files
import shutil
shutil.copyfile('sorce.txt','dest.txt')
# Out:
# 'dest.txt'

# %%
# Data Serilization

import json
data = {'name':'Suman', 'age':25}
json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Suman", "age": 25}
# <class 'str'>
# {'name': 'Suman', 'age': 25}
# <class 'dict'>

# %%
import csv
with open('example.csv', mode = 'w', newline = '') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Suman',23])
with open('example.csv', mode = 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Suman', '23']

# %%
# Date Time

from datetime import datetime, timedelta
now = datetime.now()
print(now)

yesterday = now - timedelta(days = 1)

print(yesterday)
# Out:
# 2026-03-10 14:09:23.974431
# 2026-03-09 14:09:23.974431

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1773132127.6509082
# 1773132129.6519432

# %%
# Regular Expression

import re
pattern = r'\d+'
text = 'There are 123 apples 456'
match = re.search(pattern,text)
print(match.group())
# Out:
# 123
